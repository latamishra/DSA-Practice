# %%
# %pip install pandas numpy
# Out:
# 385.26s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 5.3 MB/s  0:00:015.1 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 7.3 MB/s  0:00:007.9 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# 667.11s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 3.0 MB/s  0:00:022.9 MB/s eta 0:00:01:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.4 MB/s  0:00:003.3 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 5.6 MB/s  0:00:005.9 MB/s eta 0:00:01:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]━━━ 6/8 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data = [[1,2,3],[4,5,6]]
df = pd.DataFrame(data, columns=["num1", "num2","num3"], index=['A','B'])
df
# Out:
#    num1  num2  num3
# A     1     2     3
# B     4     5     6

# %%
id = [i for i in range(2)]
df['ID'] = id
df.set_index('ID', inplace=True)
print(df)
df.drop(columns='id',inplace=True)
# Out:
#     num1  num2  num3  id
# ID
# 0      1     2     3   0
# 1      4     5     6   1

# %%
df.index = [str(i)+"." for i in range(1,3)]

# %%
df
# Out:
#     num1  num2  num3
# 1.     1     2     3
# 2.     4     5     6

# %%
import string
df.index = list(string.ascii_lowercase[:len(df)])#ascii_uppercase is there
df
# Out:
#    num1  num2  num3
# a     1     2     3
# b     4     5     6

# %%
# %pip install matplotlib
# Out:
# 19113.86s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.plot()
# Out:
# <Axes: >

# %%
csv_url = "https://raw.githubusercontent.com/paiml/wine-ratings/main/wine-ratings.csv"

# %%
df = pd.read_csv(csv_url,index_col=0)#index_col=0 use first column as index (rembember axis=1 for column)
df.head()
# Out:
#                                                 name  grape  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    NaN
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    NaN
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    NaN
#
#                     region   variety  rating  \
# 0    Mendocino, California  Red Wine    91.0
# 1               California  Red Wine    89.0
# 2               California  Red Wine    90.0
# 3  North Coast, California  Red Wine    91.0
# 4               California  Red Wine    90.0
#
#                                                notes
# 0  This is a very special, limited release of 100...
# 1  The California Gold Rush was a period of coura...
# 2  The California Gold Rush was a period of coura...
# 3  The wine has a deep, rich purple color. An int...
# 4  Batch #004 is the first release of the 2014 vi...
